# %% [markdown]
# <a href="https://colab.research.google.com/github/irenecliu/multi-agent-customer-service/blob/main/multi_agent_customer_service.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Multi-Agent Customer Service System (A2A + MCP)
# Name: Irene
# Course: Applied Generative AI – Assignment 5
# This notebook demonstrates:
# 1. MCP customer database
# 2. Three agents (Router, Data, Support)
# 3. A2A coordination for customer service tasks
